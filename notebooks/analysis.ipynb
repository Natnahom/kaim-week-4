# %%
import os, sys

notebook_dir = os.getcwd()

#add path
sys.path.append(os.path.abspath(os.path.join(notebook_dir, '..')))

# %%
from scripts.correlation_and_behaviors import *
from scripts.data_cleaning import *
from scripts.eda import *
import pandas as pd

# %%
dataTr = '../../Data/rossmann-store-sales/train.csv'
dataTs = '../../Data/rossmann-store-sales/store.csv'

# clean the data
train_data, store_data = data_cleaning(dataTr, dataTs)

# train_data = pd.read_csv(dataTr)
# train_data.head(5)
# Out:
# c:\Users\pc\Desktop\10_Academy\Week-4\kaim-week-4\scripts\data_cleaning.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data = pd.read_csv(sales_file)

# %%
# Sales behavior before, during, and after holidays
distribution_of_promotions(train_data, store_data)

# %%
sales_behavior_holidays(train_data)

# %%
seasonal_purchase_behaviors(train_data)

# %%
correlation_sales_customers(train_data)
# Out:
# Correlation between Sales and Customers: 0.8868414857905192

# %%
impact_of_promotions(train_data)
